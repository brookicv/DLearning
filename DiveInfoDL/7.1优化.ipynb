# %%
import d2lzh as d2l
from mpl_toolkits import mplot3d #三维画图
import numpy as np 
import matplotlib.pyplot as plt 

def f(x):
    return x * np.cos(np.pi * x)

x = np.arange(-1.0,2.0,0.1)
fig, = plt.plot(x,f(x))
fig.axes.annotate("local minimum",xy = (-0.3,-0.25),xytext=(-0.77,-1.0),arrowprops=dict(arrowstyle="->"))
fig.axes.annotate("global minimum",xy = (1.1,-0.95),xytext=(0.6,0.8),arrowprops=dict(arrowstyle="->"))

plt.xlabel("x")
plt.ylabel("f(x")

plt.show()

# %% [markdown]
# ## 鞍点

# %%
x = np.arange(-2.0,2.0,0.1)
fig, = plt.plot(x,x**3)
fig.axes.annotate("saddle point",xy=(0,-0.2),xytext=(-0.52,-5.0),arrowprops=dict(arrowstyle="->"))
plt.xlabel("x")
plt.ylabel("f(x)")
# Out:
# Text(0, 0.5, 'f(x)')

# %%
x,y = np.mgrid[-1:1:32j,-1:1:31j]
z = x**2 - y**2

ax = plt.figure().add_subplot(111,projection="3d")
ax.plot_wireframe(x,y,z,**{"rstride":2,"cstride":2})
ax.plot([0],[0],[0],"rx")
ticks = [-1,0,1]
plt.xticks(ticks)
plt.yticks(ticks)
ax.set_zticks(ticks)
plt.xlabel("x")
plt.ylabel("y")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-d0091d8e0dd9> in <module>
#       3
#       4 ax = plt.figure().add_subplot(111,projection="3d")
# ----> 5 ax.plot_wireframe(x,y,z,**{"restride":2,"cstride":2})
#       6 ax.plot([0],[0],[0],"rx")
#       7 ticks = [-1,0,1]
#
# ~\Anaconda3\envs\pytorch1\lib\site-packages\mpl_toolkits\mplot3d\axes3d.py in plot_wireframe(self, X, Y, Z, *args, **kwargs)
#    1794                  for xl, yl, zl in zip(txlines, tylines, tzlines)])
#    1795
# -> 1796         linec = art3d.Line3DCollection(lines, *args, **kwargs)
#    1797         self.add_collection(linec)
#    1798         self.auto_scale_xyz(X, Y, Z, had_data)
#
# ~\Anaconda3\envs\pytorch1\lib\site-packages\matplotlib\collections.py in __init__(self, segments, linewidths, colors, antialiaseds, linestyles, offsets, transOffset, norm, cmap, pickradius, zorder, facecolors, **kwargs)
#    1356             pickradius=pickradius,
#    1357             zorder=zorder,
# -> 1358             **kwargs)
#    1359
#    1360         self.set_segments(segments)
#
# ~\Anaconda3\envs\pytorch1\lib\site-packages\matplotlib\collections.py in __init__(self, edgecolors, facecolors, linewidths, linestyles, capstyle, joinstyle, antialiaseds, offsets, transOffset, norm, cmap, pickradius, hatch, urls, offset_position, zorder, **kwargs)
#     162
#     163         self._path_effects = None
# --> 164         self.update(kwargs)
#     165         self._paths = None
#     166
#
# ~\Anaconda3\envs\pytorch1\lib\site-packages\matplotlib\artist.py in update(self, props)
#    1004
#    1005         with cbook._setattr_cm(self, eventson=False):
# -> 1006             ret = [_update_property(self, k, v) for k, v in props.items()]
#    1007
#    1008         if len(ret):
#
# ~\Anaconda3\envs\pytorch1\lib\site-packages\matplotlib\artist.py in <listcomp>(.0)
#    1004
#    1005         with cbook._setattr_cm(self, eventson=False):
# -> 1006             ret = [_update_property(self, k, v) for k, v in props.items()]
#    1007
#    1008         if len(ret):
#
# ~\Anaconda3\envs\pytorch1\lib\site-packages\matplotlib\artist.py in _update_property(self, k, v)
#    1000                 if not callable(func):
#    1001                     raise AttributeError('{!r} object has no property {!r}'
# -> 1002                                          .format(type(self).__name__, k))
#    1003                 return func(v)
#    1004
#
# AttributeError: 'Line3DCollection' object has no property 'restride'
